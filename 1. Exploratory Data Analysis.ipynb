# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
pd.options.display.max_columns = 200
pd.options.display.max_rows = 400
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('state.csv')

# %%
df.describe()
# Out:
#          Population  Murder.Rate
# count  5.000000e+01    50.000000
# mean   6.162876e+06     4.066000
# std    6.848235e+06     1.915736
# min    5.636260e+05     0.900000
# 25%    1.833004e+06     2.425000
# 50%    4.436370e+06     4.000000
# 75%    6.680312e+06     5.550000
# max    3.725396e+07    10.300000

# %%
df.Population.median()
# Out:
# 4436369.5

# %%
sns.catplot(y="Population", kind="box", data=df, height=6);

# %%
df['Population'].hist(bins=11);

# %%
sns.distplot(df['Murder.Rate'], bins=11);

# %%
df = pd.read_csv('kc_tax.csv')
df = df[(df.TaxAssessedValue < 750000) & (df.SqFtTotLiving > 100) & (df.SqFtTotLiving < 3500)]

# %%
sns.jointplot("SqFtTotLiving", "TaxAssessedValue", data=df, kind="hex");
